# %% [markdown]
# ### 가설2 - 뇌졸중 발병 요인에 성별, 나이, 고혈압, BMI는 음의 상관관계가 있을 것이다.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob
import koreanize_matplotlib
import pingouin as pg
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# %%
# 데이터 불러오기
url = "https://raw.githubusercontent.com/moksu27/midproject/main/healthcare-dataset-stroke-data.csv"
df = pd.read_csv(url)
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## 데이터 전처리

# %%
age_list=[]
for age in df["age"]:
    if age >= 0 and age <10:
        age_list.append("10대 이전")
    elif age >= 10 and age <20:
        age_list.append("10대")
    elif age >= 20 and age <30:
        age_list.append("20대")
    elif age >= 30 and age <40:
        age_list.append("30대")
    elif age >= 40 and age <50:
        age_list.append("40대")
    elif age >= 50 and age <60:
        age_list.append("50대")
    elif age >= 60 and age <70:
        age_list.append("60대")
    elif age >= 70 and age <80:
        age_list.append("70대")
    elif age >= 80 and age <90:
        age_list.append("80대")
    
df["age_group"] = age_list

# %%
#결측치 확인
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# age_group              0
# dtype: int64

# %% [markdown]
# ## bmi 결측치 제거

# %%
fill_list = df["bmi"].dropna()
df1 = df["bmi"].fillna(pd.Series(np.random.choice(fill_list, size=len(df.index))))

# %%
df1.isnull().sum()
# Out:
# 0

# %%
df["bmi"] = df1

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# age_group            0
# dtype: int64

# %% [markdown]
# ## 성별 Other 제거

# %%
df = df.loc[(df["gender"] == "Male") | (df["gender"] == "Female") ]
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  30.9     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke age_group
# 0       1       60대
# 1       1       60대
# 2       1       80대
# 3       1       40대
# 4       1       70대

# %%
#Male 은 0, Female은 1 변경
df["gender"] = df["gender"].map({"Male" : 0, "Female" : 1})
# Out:
# /var/folders/k5/knpgq_1j4xg_p46vnk55j0gm0000gn/T/ipykernel_91871/2461377197.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender"] = df["gender"].map({"Male" : 0, "Female" : 1})

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046       0  67.0             0              1          Yes
# 1  51676       1  61.0             0              0          Yes
# 2  31112       0  80.0             0              1          Yes
# 3  60182       1  49.0             0              0          Yes
# 4   1665       1  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  30.9     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke age_group
# 0       1       60대
# 1       1       60대
# 2       1       80대
# 3       1       40대
# 4       1       70대

# %%
df_sample = df[["stroke","gender","age","hypertension","bmi"]]

# %% [markdown]
# ## Scaling

# %%
stroke_scale = df_sample.iloc[:, 1:]
stroke_scale.reset_index()
norm_scaler = MinMaxScaler()
stroke_scale = norm_scaler.fit_transform(stroke_scale.to_numpy())
stroke_scale = pd.DataFrame (stroke_scale, columns = ["gender","age","hypertension","bmi"])
stroke_scale.head()
# Out:
#    gender       age  hypertension       bmi
# 0     0.0  0.816895           0.0  0.301260
# 1     1.0  0.743652           0.0  0.235968
# 2     0.0  0.975586           0.0  0.254296
# 3     1.0  0.597168           0.0  0.276060
# 4     1.0  0.963379           1.0  0.156930

# %%
df_sample.iloc[:, 1:] = stroke_scale
# Out:
# /var/folders/k5/knpgq_1j4xg_p46vnk55j0gm0000gn/T/ipykernel_91871/3093550703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sample.iloc[:, 1:] = stroke_scale

# %%
df_sample.head()
# Out:
#    index  stroke  gender       age  hypertension       bmi
# 0    105       1     0.0  0.707031           0.0  0.127148
# 1    211       1     1.0  0.621582           0.0  0.194731
# 2     77       1     1.0  0.963379           0.0  0.158076
# 3     37       1     1.0  0.877930           1.0  0.146621
# 4    132       1     0.0  0.841309           1.0  0.300115

# %%
df_sample.isnull().sum()
# Out:
# stroke          0
# gender          1
# age             1
# hypertension    1
# bmi             1
# dtype: int64

# %%
x = df_sample.corr()
x.style.background_gradient(cmap = "rocket")
# Out:
# <style type="text/css">
# #T_0c4ed_row0_col0, #T_0c4ed_row1_col1, #T_0c4ed_row2_col2, #T_0c4ed_row3_col3, #T_0c4ed_row4_col4 {
#   background-color: #faebdd;
#   color: #000000;
# }
# #T_0c4ed_row0_col1 {
#   background-color: #06071c;
#   color: #f1f1f1;
# }
# #T_0c4ed_row0_col2 {
#   background-color: #561e4f;
#   color: #f1f1f1;
# }
# #T_0c4ed_row0_col3 {
#   background-color: #37193f;
#   color: #f1f1f1;
# }
# #T_0c4ed_row0_col4 {
#   background-color: #05061b;
#   color: #f1f1f1;
# }
# #T_0c4ed_row1_col0, #T_0c4ed_row1_col2, #T_0c4ed_row1_col3, #T_0c4ed_row1_col4, #T_0c4ed_row3_col1 {
#   background-color: #03051a;
#   color: #f1f1f1;
# }
# #T_0c4ed_row2_col0 {
#   background-color: #611f53;
#   color: #f1f1f1;
# }
# #T_0c4ed_row2_col1, #T_0c4ed_row4_col1 {
#   background-color: #130d25;
#   color: #f1f1f1;
# }
# #T_0c4ed_row2_col3 {
#   background-color: #711f57;
#   color: #f1f1f1;
# }
# #T_0c4ed_row2_col4, #T_0c4ed_row4_col2 {
#   background-color: #761f58;
#   color: #f1f1f1;
# }
# #T_0c4ed_row3_col0, #T_0c4ed_row3_col4 {
#   background-color: #33183c;
#   color: #f1f1f1;
# }
# #T_0c4ed_row3_col2 {
#   background-color: #631f53;
#   color: #f1f1f1;
# }
# #T_0c4ed_row4_col0 {
#   background-color: #110c24;
#   color: #f1f1f1;
# }
# #T_0c4ed_row4_col3 {
#   background-color: #421b45;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0c4ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c4ed_level0_col0" class="col_heading level0 col0" >stroke</th>
#       <th id="T_0c4ed_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_0c4ed_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_0c4ed_level0_col3" class="col_heading level0 col3" >hypertension</th>
#       <th id="T_0c4ed_level0_col4" class="col_heading level0 col4" >bmi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c4ed_level0_row0" class="row_heading level0 row0" >stroke</th>
#       <td id="T_0c4ed_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0c4ed_row0_col1" class="data row0 col1" >-0.009044</td>
#       <td id="T_0c4ed_row0_col2" class="data row0 col2" >0.245228</td>
#       <td id="T_0c4ed_row0_col3" class="data row0 col3" >0.127879</td>
#       <td id="T_0c4ed_row0_col4" class="data row0 col4" >0.034699</td>
#     </tr>
#     <tr>
#       <th id="T_0c4ed_level0_row1" class="row_heading level0 row1" >gender</th>
#       <td id="T_0c4ed_row1_col0" class="data row1 col0" >-0.009044</td>
#       <td id="T_0c4ed_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0c4ed_row1_col2" class="data row1 col2" >0.028009</td>
#       <td id="T_0c4ed_row1_col3" class="data row1 col3" >-0.021171</td>
#       <td id="T_0c4ed_row1_col4" class="data row1 col4" >0.027033</td>
#     </tr>
#     <tr>
#       <th id="T_0c4ed_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_0c4ed_row2_col0" class="data row2 col0" >0.245228</td>
#       <td id="T_0c4ed_row2_col1" class="data row2 col1" >0.028009</td>
#       <td id="T_0c4ed_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0c4ed_row2_col3" class="data row2 col3" >0.276335</td>
#       <td id="T_0c4ed_row2_col4" class="data row2 col4" >0.320429</td>
#     </tr>
#     <tr>
#       <th id="T_0c4ed_level0_row3" class="row_heading level0 row3" >hypertension</th>
#       <td id="T_0c4ed_row3_col0" class="data row3 col0" >0.127879</td>
#       <td id="T_0c4ed_row3_col1" class="data row3 col1" >-0.021171</td>
#       <td id="T_0c4ed_row3_col2" class="data row3 col2" >0.276335</td>
#       <td id="T_0c4ed_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0c4ed_row3_col4" class="data row3 col4" >0.157007</td>
#     </tr>
#     <tr>
#       <th id="T_0c4ed_level0_row4" class="row_heading level0 row4" >bmi</th>
#       <td id="T_0c4ed_row4_col0" class="data row4 col0" >0.034699</td>
#       <td id="T_0c4ed_row4_col1" class="data row4 col1" >0.027033</td>
#       <td id="T_0c4ed_row4_col2" class="data row4 col2" >0.320429</td>
#       <td id="T_0c4ed_row4_col3" class="data row4 col3" >0.157007</td>
#       <td id="T_0c4ed_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Sampling

# %%
df_sample["stroke"].value_counts()
# Out:
# 0    4860
# 1     249
# Name: stroke, dtype: int64

# %%
class1 = df_sample.loc[(df_sample["stroke"]==1)]
class1.head()
# Out:
#    stroke  gender       age  hypertension       bmi
# 0       1     0.0  0.816895           0.0  0.301260
# 1       1     1.0  0.743652           0.0  0.235968
# 2       1     0.0  0.975586           0.0  0.254296
# 3       1     1.0  0.597168           0.0  0.276060
# 4       1     1.0  0.963379           1.0  0.156930

# %%
class0 = df_sample.loc[(df_sample["stroke"]==0)]
class0.head()
# Out:
#      stroke  gender       age  hypertension       bmi
# 249       0     0.0  0.035645           0.0  0.088202
# 250       0     0.0  0.707031           1.0  0.331042
# 251       0     1.0  0.096680           0.0  0.083620
# 252       0     1.0  0.853516           0.0  0.293242
# 253       0     0.0  0.169922           0.0  0.100802

# %% [markdown]
# # oversampling

# %%
class1_over = class1.sample(df_sample["stroke"].value_counts()[0], replace=True)
test_over = pd.concat([class1_over, class0], axis=0)
test_over.shape
# Out:
# (9720, 5)

# %%
test_over["stroke"].value_counts()
# Out:
# 1    4860
# 0    4860
# Name: stroke, dtype: int64

# %%
df_sample = test_over.copy().reset_index()
df_sample.head()
# Out:
#    index  stroke  gender       age  hypertension       bmi
# 0    105       1     0.0  0.707031           0.0  0.127148
# 1    211       1     1.0  0.621582           0.0  0.194731
# 2     77       1     1.0  0.963379           0.0  0.158076
# 3     37       1     1.0  0.877930           1.0  0.146621
# 4    132       1     0.0  0.841309           1.0  0.300115

# %% [markdown]
# ## 상관계수 구하기

# %%
mask = np.triu(np.ones_like(df_sample.corr()))

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df_sample.corr(),annot=True,cmap="coolwarm", mask=mask)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## 데이터 시각화

# %%
sns.barplot(data = df_sample, x = "gender", y="stroke")
# Out:
# <AxesSubplot: xlabel='gender', ylabel='stroke'>

# %%
sns.histplot(data = df_sample, x ="age", hue = "stroke", kde = True)
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data = df_sample , x = "bmi" , hue = "stroke")
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='Count'>

# %%
sns.kdeplot(data = df_sample, x = "bmi")
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='Density'>

# %%
sns.relplot(data = df_sample, x = "hypertension", y = "stroke", kind = "line")

# %%
sns.barplot(data = df_sample, x = "hypertension", y = "stroke")
# Out:
# <AxesSubplot: xlabel='hypertension', ylabel='stroke'>

# %% [markdown]
# ## 결론

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df_sample.corr(),annot=True,cmap="coolwarm", mask=mask)
# Out:
# <AxesSubplot: >

# %% [markdown]
# 전처리된 데이터를 통한 상관관계 분석 결과 bmi와 성별은 뇌졸중과 관련이 없으며 고혈압은 약한 양적 선형관계, 나이는 뚜렷한 양적 선형관계를 나타내고 있다.
